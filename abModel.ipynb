# %%
import pybaseball as pyb
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical

# %%
def classifyOutcome(series):
    # Types of events we classify as strikes, fouls, balls, and field outs
    strikeEvents = np.array(["foul_tip", "called_strike", "swinging_strike", "swinging_strike_blocked", "missed_bunt"])
    foulEvents = np.array(["foul", "foul_bunt"])
    ballEvents = np.array(["ball", "blocked_ball"])
    outEvents = np.array(["force_out","field_error","field_out","fielders_choice","fielders_choice_out","grounded_into_double_play","double_play","sac_fly"])

    events = series["events"]
    description = series["description"]

    out = np.zeros(8, dtype=int)

    if np.isin(description, strikeEvents):
        return "K"
    elif np.isin(description, ballEvents):
        return "B"
    elif np.isin(description, foulEvents):
        return "F"
    elif np.isin(events, outEvents):
        return "FO"
    elif events == "hit_by_pitch":
        return "HBP"
    elif events == "single":
        return "1B"
    elif events == "double":
        return "2B"
    elif events == "home_run":
        return "HR"

def processData(df) -> pd.DataFrame:
    pd.options.mode.chained_assignment = None  # default='warn'
    df = df[["pitch_type","events","description","release_speed","release_spin_rate","balls","strikes","pfx_x","pfx_z","plate_x","plate_z","vx0","vy0","vz0"]]

    outcomes = df.apply(classifyOutcome, axis=1)

    df["Outcome"] = outcomes

    df = df.drop(["events", "description"], axis=1)

    df = df.dropna()
    
    return df

# %%
class player:
    def __init__(self, **lookup)-> None:
        pyb.cache.enable()

        playerID = pd.Series(dtype=object)

        # Maybe we have a key?
        for key in ("key_mlbam","key_retro","key_bbref","key_fangraphs"):
            l = lookup.get(key)

            if not (l == None):
                playerID = pyb.playerid_reverse_lookup([l], key_type=key[4:])
        
        # If we still haven't found anyone, see if a name has been given
        if not ((lookup.get("name_first")) == None or (lookup.get("name_last") == None)) and (playerID.shape[0] == 0):
            playerID = pyb.playerid_lookup(first = lookup.get("name_first"), last = lookup.get("name_last"))

        if (playerID.shape[0] == 0):
            # PlayerID still empty, throw exception

            raise AssertionError(str("Failed to find player with these inputs or insufficient information given:\n" + str(lookup)))
        elif (playerID.shape[0] > 1):
            # Found several players, warn that we will be using the first one
            print("Warning: Found", playerID.shape[0], "players with input\n", str(lookup), "\nDefaulting to the first player!")

        self.playerID = playerID.iloc[0]
        self.playerName = (self.playerID["name_first"] + " " + self.playerID["name_last"]).title()

    def getStatcastData(self, playerType = str, dateRange = [], verbose = False) -> pd.DataFrame:
        # By default we will get pitches from games between today and 01/01/(last year)
        if dateRange == []:
            from datetime import date
            today = date.today()

            jan1LastYear = str(today.year - 1) + "-01-01"

            dateRange.append(jan1LastYear)
            dateRange.append(today.strftime("%Y-%m-%d"))

        if playerType.lower() == "batter":
            getSC = pyb.statcast_batter
        else:
            getSC = pyb.statcast_pitcher

        statcastData = getSC(start_dt = dateRange[0], end_dt = dateRange[1], player_id = self.playerID["key_mlbam"])

        if verbose:
            print(playerType.title() + ": " + self.playerName)
            print("Found " + str(statcastData.shape[0]) + " observations from " + dateRange[0] + " to " + dateRange[1] + ".\n")

        self.statcastData = statcastData

        return statcastData

# %%
pitcher = player(name_first = "Gerrit", name_last = "Cole")
batter = player(key_mlbam = 545361) # Mike Trout

# %%
batter.getStatcastData(playerType="batter", verbose=True, dateRange=["2019-01-01","2022-01-01"])
# Out:
# Gathering Player Data
# Batter: Mike Trout
# Found 4480 observations from 2019-01-01 to 2022-01-01.
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2021-05-17           95.1           1.85           6.60
# 1            FF  2021-05-17           93.6           1.58           6.66
# 2            CU  2021-05-17           80.2           1.64           6.77
# 3            CU  2021-05-17           79.7           1.70           6.64
# 4            FF  2021-05-17           94.6           1.79           6.66
# ...         ...         ...            ...            ...            ...
# 4475        NaN  2019-02-26            NaN            NaN            NaN
# 4476        NaN  2019-02-26            NaN            NaN            NaN
# 4477        NaN  2019-02-26            NaN            NaN            NaN
# 4478        NaN  2019-02-24            NaN            NaN            NaN
# 4479        NaN  2019-02-24            NaN            NaN            NaN
#
#       player_name  batter  pitcher                     events    description  \
# 0     Trout, Mike  545361   656529                       walk           ball
# 1     Trout, Mike  545361   656529                        NaN           ball
# 2     Trout, Mike  545361   656529                        NaN  called_strike
# 3     Trout, Mike  545361   656529                        NaN           ball
# 4     Trout, Mike  545361   656529                        NaN           ball
# ...           ...     ...      ...                        ...            ...
# 4475  Trout, Mike  545361   407845                        NaN           ball
# 4476  Trout, Mike  545361   407845                        NaN           ball
# 4477  Trout, Mike  545361   571666                     single  hit_into_play
# 4478  Trout, Mike  545361   607219  grounded_into_double_play  hit_into_play
# 4479  Trout, Mike  545361   661269                  field_out  hit_into_play
#
#       ...  fld_score  post_away_score  post_home_score  post_bat_score  \
# 0     ...          1                1                0               0
# 1     ...          1                1                0               0
# 2     ...          1                1                0               0
# 3     ...          1                1                0               0
# 4     ...          1                1                0               0
# ...   ...        ...              ...              ...             ...
# 4475  ...          3                3                3               3
# 4476  ...          3                3                3               3
# 4477  ...          0                0                0               0
# 4478  ...          5                5                0               0
# 4479  ...          1                1                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 0                  1              Standard              Standard     136.0
# 1                  1              Standard              Standard     146.0
# 2                  1              Standard              Standard     321.0
# 3                  1              Standard              Standard     321.0
# 4                  1              Standard              Standard     144.0
# ...              ...                   ...                   ...       ...
# 4475               3                   NaN                   NaN       NaN
# 4476               3                   NaN                   NaN       NaN
# 4477               0                   NaN                   NaN       NaN
# 4478               5                   NaN                   NaN       NaN
# 4479               1                   NaN                   NaN       NaN
#
#      delta_home_win_exp delta_run_exp
# 0                 0.022         0.187
# 1                 0.016         0.137
# 2                 0.000        -0.061
# 3                 0.000         0.070
# 4                 0.000         0.047
# ...                 ...           ...
# 4475              0.000           NaN
# 4476              0.000           NaN
# 4477             -0.036           NaN
# 4478             -0.048           NaN
# 4479             -0.023           NaN
#
# [4480 rows x 92 columns]

# %%
categories = {
    "K":    0,
    "B":    1,
    "F":    2,
    "FO":   3,
    "HBP":  4,
    "1B":   5,
    "2B":   6,
    "HR":   7,
}

# %%
sd["Outcome"] = sd["Outcome"].apply(lambda x: categories.get(x)).astype(int).apply(to_categorical, num_classes=8, dtype=int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Users\Luke\OneDrive - WCSU\Spring 22\MAT422\mlb_at_bats\abModel.ipynb Cell 8' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Users/Luke/OneDrive%20-%20WCSU/Spring%2022/MAT422/mlb_at_bats/abModel.ipynb#ch0000007?line=0'>1</a> sd["Outcome"] = sd["Outcome"].apply(lambda x: categories.get(x)).astype(int).apply(to_categorical, num_classes=8, dtype=int)
#
# NameError: name 'sd' is not defined

# %%
sample = sd.sample(frac=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Users\Luke\OneDrive - WCSU\Spring 22\MAT422\mlb_at_bats\abModel.ipynb Cell 9' in <module>
# ----> <a href='vscode-notebook-cell:/d%3A/Users/Luke/OneDrive%20-%20WCSU/Spring%2022/MAT422/mlb_at_bats/abModel.ipynb#ch0000008?line=0'>1</a> sample = sd.sample(frac=0.2)
#
# NameError: name 'sd' is not defined

# %%
class markovModel:
    def __init__(self, pitcher = player, batter = player, classifier = "logistic", verbose = False) -> None:
        dataFeatures = np.array(["release_spin_rate","plate_x","plate_z","vx0","vy0","vz0"])
        
        # We will store data here
        self.modelData = dict()

        # See if the batter object has already been initialized with data, otherwise init with default settings.
        try:
            data = batter.statcastData
        except AttributeError:
            data = batter.getStatcastData(playerType="batter")
        finally:
            self.modelData["batter"] = processData(data)

        # See if the pitcher object has already been initialized with data, otherwise init with default settings.
        try:
            data = pitcher.statcastData
        except AttributeError:
            data = pitcher.getStatcastData(playerType="pitcher")
        finally:
            self.modelData["pitcher"] = processData(data)

        self.pitcher = pitcher
        self.batter = batter

        batterTest = self.modelData["batter"].sample(frac=0.2)
        batterTrain = pd.concat([self.modelData["batter"], batterTest]).drop_duplicates(keep=False)

        if classifier == "logistic":
            from sklearn import linear_model
            model = linear_model.LogisticRegression(multi_class='multinomial')

            X_train = batterTrain[dataFeatures].values
            y_train = batterTrain["Outcome"].values

            X_test = batterTest[dataFeatures].values
            y_test = batterTest["Outcome"].values

            self.batterModel = model.fit(X_train, y_train)

            self.score = model.score(X_test, y_test)

            if verbose:
                print("Model accuracy score:", self.score)

                print(metrics.classification_report(y_test, model.predict(X_test)))

        elif classifier == "neural":
            # Have to convert into categorical type that keras accepts
            categories = {
                "K":    0,
                "B":    1,
                "F":    2,
                "FO":   3,
                "HBP":  4,
                "1B":   5,
                "2B":   6,
                "HR":   7,
            }
            data = self.modelData["batter"]
            data["Outcome"] = data["Outcome"].apply(lambda x: categories.get(x)).astype(int).apply(to_categorical, num_classes=8, dtype=int)
            print(data)

# %%
markovModel(pitcher, batter, classifier="logistic", verbose=True)
# Out:
# Model accuracy score: 0.44457831325301206
#               precision    recall  f1-score   support
#
#           1B       0.00      0.00      0.00        24
#           2B       0.00      0.00      0.00         8
#            B       0.44      1.00      0.62       369
#            F       0.00      0.00      0.00       120
#           FO       0.00      0.00      0.00        71
#          HBP       0.00      0.00      0.00         5
#           HR       0.00      0.00      0.00        10
#            K       0.00      0.00      0.00       223
#
#     accuracy                           0.44       830
#    macro avg       0.06      0.12      0.08       830
# weighted avg       0.20      0.44      0.27       830
# d:\Users\Luke\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# d:\Users\Luke\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Users\Luke\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# d:\Users\Luke\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def swingOrTake(x):
    # Types of events we classify as strikes, fouls, balls, and field outs
    swingEvents = np.array([
        "foul_tip", "foul", "foul_bunt", "swinging_strike", "swinging_strike_blocked", 
        "missed_bunt", "force_out","field_error","field_out","fielders_choice","fielders_choice_out",
        "grounded_into_double_play","double_play","sac_fly","single","double","triple","home_run"])
    takeEvents = np.array(["called_strike", "ball", "blocked_ball", "hit_by_pitch"])

    events = x["events"]
    description = x["description"]

    if np.isin(description, swingEvents):
        return 1
    elif np.isin(description, takeEvents):
        return 0
    elif np.isin(events, swingEvents):
        return 1
    elif np.isin(events, takeEvents):
        return 0

def ballsAndStrikes(x):
    b = x["balls"]
    s = x["strikes"]

    return 3*b + s

cols = pd.Series([
    # "release_speed",
    "release_spin_rate",
    "pfx_x",
    "pfx_z",
    "plate_x",
    "plate_z",
    "vx0",
    "vy0",
    "vz0"
])

def verifyModel(x):
    batter = player(key_fangraphs = x)
    print(batter.playerName)
    bd = batter.getStatcastData(dateRange=["2021-01-01","2022-01-01"], playerType="batter")

    swings = bd.apply(swingOrTake, axis=1)
    counts = pd.DataFrame(to_categorical(bd.apply(ballsAndStrikes, axis=1), num_classes=12), dtype=int).rename(lambda x: "c" + str(x), axis=1)

    bd = bd[cols]

    bd["plate_xz"] = np.sqrt(np.power(bd["plate_x"], 2) + np.power(bd["plate_z"], 2))
    bd = bd.join(counts)

    bd["Swing"] = swings
    bd = bd.dropna().astype({"Swing": int})

    bd_test = bd.sample(frac=0.1)
    bd_train = pd.concat([bd, bd_test]).drop_duplicates(keep=False)

    y_train = bd_train["Swing"].values
    X_train = bd_train.drop("Swing", axis=1).values

    y_test = bd_test["Swing"].values
    X_test = bd_test.drop("Swing", axis=1).values

    # print(np.round(bd[features].corr(method="pearson"), 3))

    scaler = preprocessing.StandardScaler().fit(X_train)

    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    bd = None

    # Logistic Model
    lm = linear_model.LogisticRegression()
    lm.fit(X_train, y_train)
    ms = np.round(lm.score(X_test, y_test), 3)

    # Neural Network Model
    neural = Sequential()
    neural.add(Dense(8, input_dim=X_train.shape[1], activation='relu'))
    neural.add(Dense(5, activation='softmax'))
    neural.add(Dense(1, activation='sigmoid'))

    neural.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

    neural.fit(X_train, y_train, epochs=100, batch_size=10)

    ns = neural.evaluate(X_test, y_test)[1]

    # print(np.round(lm.score(X_test, y_test), 3))

    # # print(metrics.classification_report(y_test, model.predict(X_test)))

    # print(np.round(lm.score(X_test, y_test), 3))

    # print(metrics.classification_report(y_test, lm.predict(X_test)))

    #print(neural.evaluate(X_test, y_test))

    return pd.Series([batter.playerName, int(batter.statcastData.shape[0]*0.8), ms, ns], index=["Name","n","Logistic", "Neural"])

# %%
bd = batter.statcastData

swings = bd.apply(swingOrTake, axis=1)
counts = pd.DataFrame(to_categorical(bd.apply(ballsAndStrikes, axis=1), num_classes=12), dtype=int).rename(lambda x: "c" + str(x), axis=1)

bd["plate_xz"] = np.sqrt(np.power(bd["plate_x"], 2) + np.power(bd["plate_z"], 2))

bd = bd[cols]
bd = bd.join(counts)

bd["Swing"] = swings
bd = bd.dropna().astype({"Swing": int})

features = pd.Series(bd.columns.values)

bd_test = bd.sample(frac=0.2)
bd_train = pd.concat([bd, bd_test]).drop_duplicates(keep=False)

y_train = bd_train["Swing"].values
X_train = bd_train.drop("Swing", axis=1).values

y_test = bd_test["Swing"].values
X_test = bd_test.drop("Swing", axis=1).values

print(np.round(bd[features].corr(method="pearson"), 3))

scaler = preprocessing.StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

bd = None

# Logistic Model
lm = linear_model.LogisticRegression()
lm.fit(X_train, y_train)
ms = np.round(lm.score(X_test, y_test), 3)

# Neural Network Model
# neural = Sequential()
# neural.add(Dense(8, input_dim=features.shape[0], activation='softmax'))
# neural.add(Dense(5, input_dim=features.shape[0], activation='softplus'))
# neural.add(Dense(1, activation='sigmoid'))

# neural.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# neural.fit(X_train, y_train, epochs=150, batch_size=10, verbose=0)

ns = 0#neural.evaluate(X_test, y_test)[1]

# print(np.round(lm.score(X_test, y_test), 3))

# # print(metrics.classification_report(y_test, model.predict(X_test)))

# print(np.round(lm.score(X_test, y_test), 3))

# print(metrics.classification_report(y_test, lm.predict(X_test)))

#print(neural.evaluate(X_test, y_test))
# Out:
#                    release_spin_rate  pfx_x  pfx_z  plate_x  plate_z  \
# release_spin_rate              1.000  0.150 -0.168    0.101   -0.007
# pfx_x                          0.150  1.000 -0.241    0.205   -0.048
# pfx_z                         -0.168 -0.241  1.000   -0.122    0.410
# plate_x                        0.101  0.205 -0.122    1.000   -0.218
# plate_z                       -0.007 -0.048  0.410   -0.218    1.000
# plate_xz                       0.023 -0.020  0.363   -0.135    0.935
# vx0                            0.094 -0.558  0.009    0.361   -0.098
# vy0                            0.015  0.329 -0.741    0.126   -0.343
# vz0                            0.072  0.208 -0.499   -0.062    0.465
# c0                             0.040  0.009 -0.003    0.005    0.015
# c1                             0.004 -0.011  0.009    0.004    0.014
# c2                             0.011 -0.002 -0.006    0.023    0.024
# c3                            -0.012 -0.006 -0.008   -0.022   -0.015
# c4                            -0.010  0.012  0.001   -0.001   -0.011
# c5                            -0.005  0.011 -0.018    0.042   -0.015
# c6                             0.005 -0.012  0.017   -0.011   -0.003
# c7                            -0.013 -0.012  0.009   -0.022    0.012
# c8                            -0.040  0.014 -0.029    0.001   -0.016
# c9                             0.012 -0.011  0.064    0.002    0.023
# c10                           -0.013  0.011  0.021   -0.000    0.005
# c11                            0.009 -0.016 -0.005   -0.027   -0.020
# Swing                         -0.031 -0.052  0.055   -0.075   -0.092
#
#                    plate_xz    vx0    vy0    vz0     c0  ...     c3     c4  \
# release_spin_rate     0.023  0.094  0.015  0.072  0.040  ... -0.012 -0.010
# pfx_x                -0.020 -0.558  0.329  0.208  0.009  ... -0.006  0.012
# pfx_z                 0.363  0.009 -0.741 -0.499 -0.003  ... -0.008  0.001
# plate_x              -0.135  0.361  0.126 -0.062  0.005  ... -0.022 -0.001
# plate_z               0.935 -0.098 -0.343  0.465  0.015  ... -0.015 -0.011
# plate_xz              1.000 -0.072 -0.310  0.454 -0.006  ... -0.026 -0.017
# vx0                  -0.072  1.000 -0.159 -0.114 -0.001  ... -0.018 -0.010
# vy0                  -0.310 -0.159  1.000  0.478  0.024  ...  0.009  0.012
# vz0                   0.454 -0.114  0.478  1.000  0.009  ... -0.001 -0.005
# c0                   -0.006 -0.001  0.024  0.009  1.000  ... -0.186 -0.185
# c1                    0.021  0.018 -0.002  0.007 -0.198  ... -0.120 -0.120
# c2                    0.064  0.016 -0.005  0.034 -0.125  ... -0.076 -0.076
# c3                   -0.026 -0.018  0.009 -0.001 -0.186  ...  1.000 -0.113
# c4                   -0.017 -0.010  0.012 -0.005 -0.185  ... -0.113  1.000
# c5                    0.014  0.011 -0.003  0.001 -0.175  ... -0.106 -0.106
# c6                   -0.014  0.004 -0.011 -0.015 -0.113  ... -0.069 -0.068
# c7                    0.002 -0.004 -0.010  0.003 -0.140  ... -0.085 -0.085
# c8                    0.001 -0.007  0.024  0.012 -0.181  ... -0.110 -0.110
# c9                    0.019  0.007 -0.058 -0.030 -0.066  ... -0.040 -0.040
# c10                  -0.000 -0.008 -0.026 -0.013 -0.098  ... -0.060 -0.060
# c11                  -0.036 -0.002 -0.019 -0.030 -0.150  ... -0.091 -0.091
# Swing                -0.200  0.003 -0.051 -0.125 -0.226  ... -0.006  0.056
#
#                       c5     c6     c7     c8     c9    c10    c11  Swing
# release_spin_rate -0.005  0.005 -0.013 -0.040  0.012 -0.013  0.009 -0.031
# pfx_x              0.011 -0.012 -0.012  0.014 -0.011  0.011 -0.016 -0.052
# pfx_z             -0.018  0.017  0.009 -0.029  0.064  0.021 -0.005  0.055
# plate_x            0.042 -0.011 -0.022  0.001  0.002 -0.000 -0.027 -0.075
# plate_z           -0.015 -0.003  0.012 -0.016  0.023  0.005 -0.020 -0.092
# plate_xz           0.014 -0.014  0.002  0.001  0.019 -0.000 -0.036 -0.200
# vx0                0.011  0.004 -0.004 -0.007  0.007 -0.008 -0.002  0.003
# vy0               -0.003 -0.011 -0.010  0.024 -0.058 -0.026 -0.019 -0.051
# vz0                0.001 -0.015  0.003  0.012 -0.030 -0.013 -0.030 -0.125
# c0                -0.175 -0.113 -0.140 -0.181 -0.066 -0.098 -0.150 -0.226
# c1                -0.113 -0.073 -0.090 -0.117 -0.043 -0.064 -0.097  0.014
# c2                -0.071 -0.046 -0.057 -0.074 -0.027 -0.040 -0.061 -0.044
# c3                -0.106 -0.069 -0.085 -0.110 -0.040 -0.060 -0.091 -0.006
# c4                -0.106 -0.068 -0.085 -0.110 -0.040 -0.060 -0.091  0.056
# c5                 1.000 -0.064 -0.080 -0.104 -0.038 -0.056 -0.086  0.028
# c6                -0.064  1.000 -0.052 -0.067 -0.024 -0.036 -0.055  0.001
# c7                -0.080 -0.052  1.000 -0.083 -0.030 -0.045 -0.069  0.040
# c8                -0.104 -0.067 -0.083  1.000 -0.039 -0.058 -0.089  0.129
# c9                -0.038 -0.024 -0.030 -0.039  1.000 -0.021 -0.033 -0.075
# c10               -0.056 -0.036 -0.045 -0.058 -0.021  1.000 -0.048  0.030
# c11               -0.086 -0.055 -0.069 -0.089 -0.033 -0.048  1.000  0.131
# Swing              0.028  0.001  0.040  0.129 -0.075  0.030  0.131  1.000
#
# [22 rows x 22 columns]
# array([[-0.68605297,  0.70997439,  0.56824935, ..., -0.11713032,
#          5.5651733 , -0.27640573],
#        [-0.6317017 ,  0.80589592,  0.59483762, ..., -0.11713032,
#         -0.17968892, -0.27640573],
#        [ 0.221933  , -0.24924092, -2.3298723 , ..., -0.11713032,
#         -0.17968892, -0.27640573],
#        ...,
#        [-0.60932176,  0.86584688,  0.54166108, ..., -0.11713032,
#         -0.17968892, -0.27640573],
#        [-1.36704246,  1.77710143, -0.36234017, ..., -0.11713032,
#         -0.17968892, -0.27640573],
#        [-0.29919979,  1.22555262,  0.46189626, ..., -0.11713032,
#         -0.17968892, -0.27640573]])

# %%
sample = pyb.batting_stats(start_season=2021, end_season=2021, qual=400)["IDfg"].sample(n=10)

# %%
scores = sample.apply(verifyModel)
scores
# Out:
# Dj Lemahieu
# Gathering Player Data
# Epoch 1/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.6961 - accuracy: 0.5205
# Epoch 2/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.6517 - accuracy: 0.6067
# Epoch 3/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.6274 - accuracy: 0.6430
# Epoch 4/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.6104 - accuracy: 0.6781
# Epoch 5/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.5933 - accuracy: 0.7050
# Epoch 6/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.5751 - accuracy: 0.7362
# Epoch 7/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.5586 - accuracy: 0.7476
# Epoch 8/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.5444 - accuracy: 0.7554
# Epoch 9/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.5319 - accuracy: 0.7639
# Epoch 10/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.5197 - accuracy: 0.7718
# Epoch 11/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.5066 - accuracy: 0.7788
# Epoch 12/100
# 257/257 [==============================] - 0s 493us/step - loss: 0.4931 - accuracy: 0.7905
# Epoch 13/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.4799 - accuracy: 0.7995
# Epoch 14/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.4678 - accuracy: 0.8049
# Epoch 15/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.4562 - accuracy: 0.8065
# Epoch 16/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.4480 - accuracy: 0.8088
# Epoch 17/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.4401 - accuracy: 0.8151
# Epoch 18/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.4350 - accuracy: 0.8143
# Epoch 19/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.4299 - accuracy: 0.8147
# Epoch 20/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.4252 - accuracy: 0.8174
# Epoch 21/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.4212 - accuracy: 0.8166
# Epoch 22/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.4181 - accuracy: 0.8155
# Epoch 23/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.4158 - accuracy: 0.8178
# Epoch 24/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.4139 - accuracy: 0.8190
# Epoch 25/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.4112 - accuracy: 0.8182
# Epoch 26/100
# 257/257 [==============================] - 0s 430us/step - loss: 0.4102 - accuracy: 0.8201
# Epoch 27/100
# 257/257 [==============================] - 0s 430us/step - loss: 0.4077 - accuracy: 0.8151
# Epoch 28/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.4060 - accuracy: 0.8178
# Epoch 29/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.4054 - accuracy: 0.8186
# Epoch 30/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.4037 - accuracy: 0.8197
# Epoch 31/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.4025 - accuracy: 0.8221
# Epoch 32/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.4018 - accuracy: 0.8213
# Epoch 33/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.4011 - accuracy: 0.8197
# Epoch 34/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.3997 - accuracy: 0.8209
# Epoch 35/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3992 - accuracy: 0.8182
# Epoch 36/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.3975 - accuracy: 0.8244
# Epoch 37/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3984 - accuracy: 0.8170
# Epoch 38/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3962 - accuracy: 0.8233
# Epoch 39/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.3958 - accuracy: 0.8213
# Epoch 40/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3955 - accuracy: 0.8201
# Epoch 41/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3944 - accuracy: 0.8268
# Epoch 42/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.3939 - accuracy: 0.8225
# Epoch 43/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3929 - accuracy: 0.8233
# Epoch 44/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3923 - accuracy: 0.8225
# Epoch 45/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3927 - accuracy: 0.8225
# Epoch 46/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3919 - accuracy: 0.8244
# Epoch 47/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3914 - accuracy: 0.8240
# Epoch 48/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3910 - accuracy: 0.8248
# Epoch 49/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3899 - accuracy: 0.8236
# Epoch 50/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3905 - accuracy: 0.8229
# Epoch 51/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3890 - accuracy: 0.8244
# Epoch 52/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3892 - accuracy: 0.8240
# Epoch 53/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3891 - accuracy: 0.8240
# Epoch 54/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3881 - accuracy: 0.8275
# Epoch 55/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3881 - accuracy: 0.8252
# Epoch 56/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3889 - accuracy: 0.8268
# Epoch 57/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3866 - accuracy: 0.8279
# Epoch 58/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3862 - accuracy: 0.8287
# Epoch 59/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3856 - accuracy: 0.8295
# Epoch 60/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3859 - accuracy: 0.8295
# Epoch 61/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3863 - accuracy: 0.8248
# Epoch 62/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3847 - accuracy: 0.8279
# Epoch 63/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3847 - accuracy: 0.8268
# Epoch 64/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3843 - accuracy: 0.8244
# Epoch 65/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3845 - accuracy: 0.8275
# Epoch 66/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3841 - accuracy: 0.8244
# Epoch 67/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3838 - accuracy: 0.8260
# Epoch 68/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3834 - accuracy: 0.8256
# Epoch 69/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3828 - accuracy: 0.8279
# Epoch 70/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3827 - accuracy: 0.8252
# Epoch 71/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3824 - accuracy: 0.8272
# Epoch 72/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3824 - accuracy: 0.8272
# Epoch 73/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3814 - accuracy: 0.8272
# Epoch 74/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3810 - accuracy: 0.8252
# Epoch 75/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3806 - accuracy: 0.8279
# Epoch 76/100
# 257/257 [==============================] - 0s 485us/step - loss: 0.3818 - accuracy: 0.8268
# Epoch 77/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3800 - accuracy: 0.8279
# Epoch 78/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3812 - accuracy: 0.8287
# Epoch 79/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3796 - accuracy: 0.8287
# Epoch 80/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3795 - accuracy: 0.8287
# Epoch 81/100
# 257/257 [==============================] - 0s 454us/step - loss: 0.3799 - accuracy: 0.8272
# Epoch 82/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3790 - accuracy: 0.8256
# Epoch 83/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3795 - accuracy: 0.8252
# Epoch 84/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3803 - accuracy: 0.8295
# Epoch 85/100
# 257/257 [==============================] - 0s 457us/step - loss: 0.3788 - accuracy: 0.8268
# Epoch 86/100
# 257/257 [==============================] - 0s 461us/step - loss: 0.3788 - accuracy: 0.8291
# Epoch 87/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3785 - accuracy: 0.8275
# Epoch 88/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3787 - accuracy: 0.8264
# Epoch 89/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3783 - accuracy: 0.8264
# Epoch 90/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3772 - accuracy: 0.8287
# Epoch 91/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3781 - accuracy: 0.8291
# Epoch 92/100
# 257/257 [==============================] - 0s 434us/step - loss: 0.3775 - accuracy: 0.8209
# Epoch 93/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3773 - accuracy: 0.8279
# Epoch 94/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3768 - accuracy: 0.8299
# Epoch 95/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3775 - accuracy: 0.8291
# Epoch 96/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3763 - accuracy: 0.8248
# Epoch 97/100
# 257/257 [==============================] - 0s 438us/step - loss: 0.3768 - accuracy: 0.8256
# Epoch 98/100
# 257/257 [==============================] - 0s 450us/step - loss: 0.3763 - accuracy: 0.8287
# Epoch 99/100
# 257/257 [==============================] - 0s 442us/step - loss: 0.3767 - accuracy: 0.8275
# Epoch 100/100
# 257/257 [==============================] - 0s 446us/step - loss: 0.3765 - accuracy: 0.8272
# 9/9 [==============================] - 0s 501us/step - loss: 0.4279 - accuracy: 0.7754
# Jonathan India
# Gathering Player Data
# Epoch 1/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.6701 - accuracy: 0.5761
# Epoch 2/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.6343 - accuracy: 0.6233
# Epoch 3/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.6090 - accuracy: 0.6564
# Epoch 4/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.5894 - accuracy: 0.6823
# Epoch 5/100
# 240/240 [==============================] - 0s 431us/step - loss: 0.5735 - accuracy: 0.7032
# Epoch 6/100
# 240/240 [==============================] - 0s 440us/step - loss: 0.5581 - accuracy: 0.7203
# Epoch 7/100
# 240/240 [==============================] - 0s 436us/step - loss: 0.5435 - accuracy: 0.7429
# Epoch 8/100
# 240/240 [==============================] - 0s 440us/step - loss: 0.5321 - accuracy: 0.7529
# Epoch 9/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.5229 - accuracy: 0.7609
# Epoch 10/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.5156 - accuracy: 0.7651
# Epoch 11/100
# 240/240 [==============================] - 0s 465us/step - loss: 0.5092 - accuracy: 0.7692
# Epoch 12/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.5052 - accuracy: 0.7713
# Epoch 13/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.5020 - accuracy: 0.7734
# Epoch 14/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4990 - accuracy: 0.7755
# Epoch 15/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.4966 - accuracy: 0.7784
# Epoch 16/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4945 - accuracy: 0.7822
# Epoch 17/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4927 - accuracy: 0.7814
# Epoch 18/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4908 - accuracy: 0.7814
# Epoch 19/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4888 - accuracy: 0.7851
# Epoch 20/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4876 - accuracy: 0.7864
# Epoch 21/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4868 - accuracy: 0.7830
# Epoch 22/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4847 - accuracy: 0.7889
# Epoch 23/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.4833 - accuracy: 0.7880
# Epoch 24/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4817 - accuracy: 0.7906
# Epoch 25/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4803 - accuracy: 0.7876
# Epoch 26/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4788 - accuracy: 0.7897
# Epoch 27/100
# 240/240 [==============================] - 0s 440us/step - loss: 0.4774 - accuracy: 0.7922
# Epoch 28/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4754 - accuracy: 0.7931
# Epoch 29/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4742 - accuracy: 0.7906
# Epoch 30/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4728 - accuracy: 0.7926
# Epoch 31/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4710 - accuracy: 0.7914
# Epoch 32/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4695 - accuracy: 0.7926
# Epoch 33/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4670 - accuracy: 0.7964
# Epoch 34/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4657 - accuracy: 0.7956
# Epoch 35/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4641 - accuracy: 0.7972
# Epoch 36/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4627 - accuracy: 0.7947
# Epoch 37/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4606 - accuracy: 0.7977
# Epoch 38/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4582 - accuracy: 0.8018
# Epoch 39/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4566 - accuracy: 0.8056
# Epoch 40/100
# 240/240 [==============================] - 0s 482us/step - loss: 0.4541 - accuracy: 0.8035
# Epoch 41/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4532 - accuracy: 0.8027
# Epoch 42/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4506 - accuracy: 0.8035
# Epoch 43/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4485 - accuracy: 0.8069
# Epoch 44/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4468 - accuracy: 0.8031
# Epoch 45/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4452 - accuracy: 0.8056
# Epoch 46/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4415 - accuracy: 0.8081
# Epoch 47/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4404 - accuracy: 0.8127
# Epoch 48/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4384 - accuracy: 0.8052
# Epoch 49/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4345 - accuracy: 0.8102
# Epoch 50/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4321 - accuracy: 0.8089
# Epoch 51/100
# 240/240 [==============================] - 0s 461us/step - loss: 0.4302 - accuracy: 0.8060
# Epoch 52/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4279 - accuracy: 0.8069
# Epoch 53/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4240 - accuracy: 0.8140
# Epoch 54/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4239 - accuracy: 0.8140
# Epoch 55/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4215 - accuracy: 0.8156
# Epoch 56/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4194 - accuracy: 0.8115
# Epoch 57/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4173 - accuracy: 0.8186
# Epoch 58/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4153 - accuracy: 0.8177
# Epoch 59/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4152 - accuracy: 0.8190
# Epoch 60/100
# 240/240 [==============================] - 0s 461us/step - loss: 0.4139 - accuracy: 0.8223
# Epoch 61/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4117 - accuracy: 0.8219
# Epoch 62/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4107 - accuracy: 0.8194
# Epoch 63/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4098 - accuracy: 0.8177
# Epoch 64/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4089 - accuracy: 0.8135
# Epoch 65/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4074 - accuracy: 0.8202
# Epoch 66/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4062 - accuracy: 0.8198
# Epoch 67/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4054 - accuracy: 0.8211
# Epoch 68/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.4041 - accuracy: 0.8202
# Epoch 69/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4025 - accuracy: 0.8207
# Epoch 70/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4025 - accuracy: 0.8253
# Epoch 71/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4020 - accuracy: 0.8202
# Epoch 72/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.4011 - accuracy: 0.8227
# Epoch 73/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.4007 - accuracy: 0.8248
# Epoch 74/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3983 - accuracy: 0.8311
# Epoch 75/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3998 - accuracy: 0.8223
# Epoch 76/100
# 240/240 [==============================] - 0s 461us/step - loss: 0.3981 - accuracy: 0.8248
# Epoch 77/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.3990 - accuracy: 0.8219
# Epoch 78/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.3957 - accuracy: 0.8303
# Epoch 79/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3965 - accuracy: 0.8244
# Epoch 80/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.3934 - accuracy: 0.8290
# Epoch 81/100
# 240/240 [==============================] - 0s 444us/step - loss: 0.3949 - accuracy: 0.8269
# Epoch 82/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3942 - accuracy: 0.8278
# Epoch 83/100
# 240/240 [==============================] - 0s 461us/step - loss: 0.3934 - accuracy: 0.8298
# Epoch 84/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3924 - accuracy: 0.8298
# Epoch 85/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3936 - accuracy: 0.8298
# Epoch 86/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3915 - accuracy: 0.8273
# Epoch 87/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3911 - accuracy: 0.8240
# Epoch 88/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3885 - accuracy: 0.8282
# Epoch 89/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3907 - accuracy: 0.8319
# Epoch 90/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3886 - accuracy: 0.8261
# Epoch 91/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.3883 - accuracy: 0.8315
# Epoch 92/100
# 240/240 [==============================] - 0s 469us/step - loss: 0.3892 - accuracy: 0.8303
# Epoch 93/100
# 240/240 [==============================] - 0s 486us/step - loss: 0.3876 - accuracy: 0.8370
# Epoch 94/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3874 - accuracy: 0.8332
# Epoch 95/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3869 - accuracy: 0.8336
# Epoch 96/100
# 240/240 [==============================] - 0s 448us/step - loss: 0.3866 - accuracy: 0.8286
# Epoch 97/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3866 - accuracy: 0.8315
# Epoch 98/100
# 240/240 [==============================] - 0s 456us/step - loss: 0.3847 - accuracy: 0.8349
# Epoch 99/100
# 240/240 [==============================] - 0s 452us/step - loss: 0.3850 - accuracy: 0.8307
# Epoch 100/100
# 240/240 [==============================] - 0s 440us/step - loss: 0.3841 - accuracy: 0.8319
# 9/9 [==============================] - 0s 500us/step - loss: 0.4910 - accuracy: 0.7444
# Kolten Wong
# Gathering Player Data
# Epoch 1/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.7063 - accuracy: 0.5199
# Epoch 2/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.6933 - accuracy: 0.5199
# Epoch 3/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.6822 - accuracy: 0.5556
# Epoch 4/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.6641 - accuracy: 0.6336
# Epoch 5/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.6421 - accuracy: 0.6758
# Epoch 6/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.6196 - accuracy: 0.7032
# Epoch 7/100
# 169/169 [==============================] - 0s 471us/step - loss: 0.5975 - accuracy: 0.7246
# Epoch 8/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.5766 - accuracy: 0.7424
# Epoch 9/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.5575 - accuracy: 0.7603
# Epoch 10/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.5403 - accuracy: 0.7650
# Epoch 11/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.5245 - accuracy: 0.7799
# Epoch 12/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.5100 - accuracy: 0.7787
# Epoch 13/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4963 - accuracy: 0.7936
# Epoch 14/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4847 - accuracy: 0.8001
# Epoch 15/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4753 - accuracy: 0.8061
# Epoch 16/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.4647 - accuracy: 0.8156
# Epoch 17/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.4565 - accuracy: 0.8144
# Epoch 18/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4491 - accuracy: 0.8198
# Epoch 19/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4430 - accuracy: 0.8192
# Epoch 20/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4374 - accuracy: 0.8186
# Epoch 21/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4329 - accuracy: 0.8233
# Epoch 22/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4286 - accuracy: 0.8251
# Epoch 23/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4246 - accuracy: 0.8239
# Epoch 24/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4209 - accuracy: 0.8269
# Epoch 25/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.4178 - accuracy: 0.8334
# Epoch 26/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.4161 - accuracy: 0.8287
# Epoch 27/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.4134 - accuracy: 0.8293
# Epoch 28/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4099 - accuracy: 0.8334
# Epoch 29/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4079 - accuracy: 0.8322
# Epoch 30/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4059 - accuracy: 0.8376
# Epoch 31/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4042 - accuracy: 0.8334
# Epoch 32/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.4024 - accuracy: 0.8370
# Epoch 33/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.4001 - accuracy: 0.8340
# Epoch 34/100
# 169/169 [==============================] - 0s 477us/step - loss: 0.3994 - accuracy: 0.8376
# Epoch 35/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3971 - accuracy: 0.8400
# Epoch 36/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3955 - accuracy: 0.8364
# Epoch 37/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3945 - accuracy: 0.8406
# Epoch 38/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3940 - accuracy: 0.8352
# Epoch 39/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3915 - accuracy: 0.8400
# Epoch 40/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3907 - accuracy: 0.8406
# Epoch 41/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3884 - accuracy: 0.8418
# Epoch 42/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3887 - accuracy: 0.8376
# Epoch 43/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3881 - accuracy: 0.8441
# Epoch 44/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3869 - accuracy: 0.8424
# Epoch 45/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3848 - accuracy: 0.8435
# Epoch 46/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3836 - accuracy: 0.8406
# Epoch 47/100
# 169/169 [==============================] - 0s 506us/step - loss: 0.3831 - accuracy: 0.8418
# Epoch 48/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3826 - accuracy: 0.8489
# Epoch 49/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3826 - accuracy: 0.8418
# Epoch 50/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3807 - accuracy: 0.8465
# Epoch 51/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3806 - accuracy: 0.8453
# Epoch 52/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.3796 - accuracy: 0.8430
# Epoch 53/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3785 - accuracy: 0.8435
# Epoch 54/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3768 - accuracy: 0.8424
# Epoch 55/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3777 - accuracy: 0.8459
# Epoch 56/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3769 - accuracy: 0.8501
# Epoch 57/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3767 - accuracy: 0.8459
# Epoch 58/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3750 - accuracy: 0.8424
# Epoch 59/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3741 - accuracy: 0.8465
# Epoch 60/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.3733 - accuracy: 0.8424
# Epoch 61/100
# 169/169 [==============================] - 0s 471us/step - loss: 0.3732 - accuracy: 0.8424
# Epoch 62/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3731 - accuracy: 0.8453
# Epoch 63/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3721 - accuracy: 0.8430
# Epoch 64/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3714 - accuracy: 0.8447
# Epoch 65/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3712 - accuracy: 0.8465
# Epoch 66/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3694 - accuracy: 0.8447
# Epoch 67/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3699 - accuracy: 0.8435
# Epoch 68/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3695 - accuracy: 0.8400
# Epoch 69/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3687 - accuracy: 0.8430
# Epoch 70/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.3684 - accuracy: 0.8453
# Epoch 71/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3676 - accuracy: 0.8400
# Epoch 72/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3672 - accuracy: 0.8441
# Epoch 73/100
# 169/169 [==============================] - 0s 435us/step - loss: 0.3672 - accuracy: 0.8430
# Epoch 74/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.3668 - accuracy: 0.8418
# Epoch 75/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3660 - accuracy: 0.8435
# Epoch 76/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3645 - accuracy: 0.8388
# Epoch 77/100
# 169/169 [==============================] - 0s 483us/step - loss: 0.3651 - accuracy: 0.8424
# Epoch 78/100
# 169/169 [==============================] - 0s 477us/step - loss: 0.3666 - accuracy: 0.8453
# Epoch 79/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.3655 - accuracy: 0.8501
# Epoch 80/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3649 - accuracy: 0.8441
# Epoch 81/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3643 - accuracy: 0.8406
# Epoch 82/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3633 - accuracy: 0.8483
# Epoch 83/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3637 - accuracy: 0.8418
# Epoch 84/100
# 169/169 [==============================] - 0s 471us/step - loss: 0.3618 - accuracy: 0.8418
# Epoch 85/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.3633 - accuracy: 0.8394
# Epoch 86/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.3639 - accuracy: 0.8412
# Epoch 87/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.3624 - accuracy: 0.8406
# Epoch 88/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3600 - accuracy: 0.8447
# Epoch 89/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3619 - accuracy: 0.8435
# Epoch 90/100
# 169/169 [==============================] - 0s 447us/step - loss: 0.3601 - accuracy: 0.8459
# Epoch 91/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3611 - accuracy: 0.8424
# Epoch 92/100
# 169/169 [==============================] - 0s 465us/step - loss: 0.3593 - accuracy: 0.8459
# Epoch 93/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3602 - accuracy: 0.8406
# Epoch 94/100
# 169/169 [==============================] - 0s 500us/step - loss: 0.3591 - accuracy: 0.8441
# Epoch 95/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3595 - accuracy: 0.8459
# Epoch 96/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3608 - accuracy: 0.8430
# Epoch 97/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3577 - accuracy: 0.8447
# Epoch 98/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3588 - accuracy: 0.8394
# Epoch 99/100
# 169/169 [==============================] - 0s 459us/step - loss: 0.3591 - accuracy: 0.8418
# Epoch 100/100
# 169/169 [==============================] - 0s 453us/step - loss: 0.3594 - accuracy: 0.8430
# 6/6 [==============================] - 0s 600us/step - loss: 0.4164 - accuracy: 0.7968
# Yuli Gurriel
# Gathering Player Data
# Epoch 1/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.6858 - accuracy: 0.5424
# Epoch 2/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.6454 - accuracy: 0.6455
# Epoch 3/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.6248 - accuracy: 0.6757
# Epoch 4/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.6082 - accuracy: 0.6932
# Epoch 5/100
# 229/229 [==============================] - 0s 470us/step - loss: 0.5947 - accuracy: 0.7019
# Epoch 6/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.5833 - accuracy: 0.7054
# Epoch 7/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.5736 - accuracy: 0.7185
# Epoch 8/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.5648 - accuracy: 0.7286
# Epoch 9/100
# 229/229 [==============================] - 0s 465us/step - loss: 0.5560 - accuracy: 0.7426
# Epoch 10/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.5477 - accuracy: 0.7474
# Epoch 11/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.5401 - accuracy: 0.7548
# Epoch 12/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.5326 - accuracy: 0.7587
# Epoch 13/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.5251 - accuracy: 0.7614
# Epoch 14/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.5181 - accuracy: 0.7649
# Epoch 15/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.5106 - accuracy: 0.7640
# Epoch 16/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.5041 - accuracy: 0.7753
# Epoch 17/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4968 - accuracy: 0.7788
# Epoch 18/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4902 - accuracy: 0.7810
# Epoch 19/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4834 - accuracy: 0.7828
# Epoch 20/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4776 - accuracy: 0.7863
# Epoch 21/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4731 - accuracy: 0.7872
# Epoch 22/100
# 229/229 [==============================] - 0s 461us/step - loss: 0.4676 - accuracy: 0.7898
# Epoch 23/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4632 - accuracy: 0.7906
# Epoch 24/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4590 - accuracy: 0.7920
# Epoch 25/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4559 - accuracy: 0.7946
# Epoch 26/100
# 229/229 [==============================] - 0s 483us/step - loss: 0.4532 - accuracy: 0.7911
# Epoch 27/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4512 - accuracy: 0.7915
# Epoch 28/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4480 - accuracy: 0.7968
# Epoch 29/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4467 - accuracy: 0.7933
# Epoch 30/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4443 - accuracy: 0.7950
# Epoch 31/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4423 - accuracy: 0.7933
# Epoch 32/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4410 - accuracy: 0.7963
# Epoch 33/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4399 - accuracy: 0.8003
# Epoch 34/100
# 229/229 [==============================] - 0s 465us/step - loss: 0.4381 - accuracy: 0.7985
# Epoch 35/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4365 - accuracy: 0.8011
# Epoch 36/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4356 - accuracy: 0.7985
# Epoch 37/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4342 - accuracy: 0.7976
# Epoch 38/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4337 - accuracy: 0.7981
# Epoch 39/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4319 - accuracy: 0.7963
# Epoch 40/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4312 - accuracy: 0.8029
# Epoch 41/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4308 - accuracy: 0.7963
# Epoch 42/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4297 - accuracy: 0.8081
# Epoch 43/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4278 - accuracy: 0.8046
# Epoch 44/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4276 - accuracy: 0.8024
# Epoch 45/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4274 - accuracy: 0.8029
# Epoch 46/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4263 - accuracy: 0.8033
# Epoch 47/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4255 - accuracy: 0.8020
# Epoch 48/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4246 - accuracy: 0.8046
# Epoch 49/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4242 - accuracy: 0.8011
# Epoch 50/100
# 229/229 [==============================] - 0s 435us/step - loss: 0.4241 - accuracy: 0.8029
# Epoch 51/100
# 229/229 [==============================] - 0s 435us/step - loss: 0.4231 - accuracy: 0.8038
# Epoch 52/100
# 229/229 [==============================] - 0s 435us/step - loss: 0.4222 - accuracy: 0.8016
# Epoch 53/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4204 - accuracy: 0.8051
# Epoch 54/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4211 - accuracy: 0.8055
# Epoch 55/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4211 - accuracy: 0.8033
# Epoch 56/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4190 - accuracy: 0.8086
# Epoch 57/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4182 - accuracy: 0.8029
# Epoch 58/100
# 229/229 [==============================] - 0s 487us/step - loss: 0.4186 - accuracy: 0.8059
# Epoch 59/100
# 229/229 [==============================] - 0s 461us/step - loss: 0.4184 - accuracy: 0.8038
# Epoch 60/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4166 - accuracy: 0.8073
# Epoch 61/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4161 - accuracy: 0.8077
# Epoch 62/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4166 - accuracy: 0.8046
# Epoch 63/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4154 - accuracy: 0.8024
# Epoch 64/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4151 - accuracy: 0.8033
# Epoch 65/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4148 - accuracy: 0.8042
# Epoch 66/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4142 - accuracy: 0.8077
# Epoch 67/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4141 - accuracy: 0.8020
# Epoch 68/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4140 - accuracy: 0.8029
# Epoch 69/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4137 - accuracy: 0.8064
# Epoch 70/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4129 - accuracy: 0.8038
# Epoch 71/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4122 - accuracy: 0.8077
# Epoch 72/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4127 - accuracy: 0.8059
# Epoch 73/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4112 - accuracy: 0.8081
# Epoch 74/100
# 229/229 [==============================] - 0s 435us/step - loss: 0.4120 - accuracy: 0.8077
# Epoch 75/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4112 - accuracy: 0.8059
# Epoch 76/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4108 - accuracy: 0.8055
# Epoch 77/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4094 - accuracy: 0.8068
# Epoch 78/100
# 229/229 [==============================] - 0s 435us/step - loss: 0.4103 - accuracy: 0.8011
# Epoch 79/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4104 - accuracy: 0.8073
# Epoch 80/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4100 - accuracy: 0.8077
# Epoch 81/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4089 - accuracy: 0.8051
# Epoch 82/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4095 - accuracy: 0.8046
# Epoch 83/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4082 - accuracy: 0.8077
# Epoch 84/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4076 - accuracy: 0.8094
# Epoch 85/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4086 - accuracy: 0.8033
# Epoch 86/100
# 229/229 [==============================] - 0s 443us/step - loss: 0.4086 - accuracy: 0.8077
# Epoch 87/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4088 - accuracy: 0.8046
# Epoch 88/100
# 229/229 [==============================] - 0s 487us/step - loss: 0.4082 - accuracy: 0.8051
# Epoch 89/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4077 - accuracy: 0.8099
# Epoch 90/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4072 - accuracy: 0.8016
# Epoch 91/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4075 - accuracy: 0.8086
# Epoch 92/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4072 - accuracy: 0.8042
# Epoch 93/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4073 - accuracy: 0.8068
# Epoch 94/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4063 - accuracy: 0.8068
# Epoch 95/100
# 229/229 [==============================] - 0s 461us/step - loss: 0.4070 - accuracy: 0.8064
# Epoch 96/100
# 229/229 [==============================] - 0s 452us/step - loss: 0.4055 - accuracy: 0.8081
# Epoch 97/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4069 - accuracy: 0.8055
# Epoch 98/100
# 229/229 [==============================] - 0s 448us/step - loss: 0.4067 - accuracy: 0.8051
# Epoch 99/100
# 229/229 [==============================] - 0s 457us/step - loss: 0.4064 - accuracy: 0.8086
# Epoch 100/100
# 229/229 [==============================] - 0s 461us/step - loss: 0.4055 - accuracy: 0.8090
# 8/8 [==============================] - 0s 572us/step - loss: 0.5476 - accuracy: 0.7283
# J. D. Martinez
# Gathering Player Data
# Epoch 1/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.6974 - accuracy: 0.5096
# Epoch 2/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.6746 - accuracy: 0.5998
# Epoch 3/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.6564 - accuracy: 0.6518
# Epoch 4/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.6420 - accuracy: 0.6616
# Epoch 5/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.6306 - accuracy: 0.6718
# Epoch 6/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.6194 - accuracy: 0.6786
# Epoch 7/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.6074 - accuracy: 0.6952
# Epoch 8/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.5948 - accuracy: 0.7020
# Epoch 9/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.5803 - accuracy: 0.7156
# Epoch 10/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.5630 - accuracy: 0.7182
# Epoch 11/100
# 235/235 [==============================] - 0s 458us/step - loss: 0.5447 - accuracy: 0.7331
# Epoch 12/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.5264 - accuracy: 0.7463
# Epoch 13/100
# 235/235 [==============================] - 0s 488us/step - loss: 0.5083 - accuracy: 0.7739
# Epoch 14/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4905 - accuracy: 0.7905
# Epoch 15/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4790 - accuracy: 0.7935
# Epoch 16/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4693 - accuracy: 0.8012
# Epoch 17/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4630 - accuracy: 0.8054
# Epoch 18/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4585 - accuracy: 0.8016
# Epoch 19/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4538 - accuracy: 0.8080
# Epoch 20/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4507 - accuracy: 0.8080
# Epoch 21/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4480 - accuracy: 0.8072
# Epoch 22/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4453 - accuracy: 0.8106
# Epoch 23/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4431 - accuracy: 0.8135
# Epoch 24/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4417 - accuracy: 0.8118
# Epoch 25/100
# 235/235 [==============================] - 0s 462us/step - loss: 0.4397 - accuracy: 0.8127
# Epoch 26/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4384 - accuracy: 0.8178
# Epoch 27/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4364 - accuracy: 0.8161
# Epoch 28/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4348 - accuracy: 0.8135
# Epoch 29/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4333 - accuracy: 0.8148
# Epoch 30/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4319 - accuracy: 0.8135
# Epoch 31/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4298 - accuracy: 0.8157
# Epoch 32/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4281 - accuracy: 0.8161
# Epoch 33/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4272 - accuracy: 0.8157
# Epoch 34/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4258 - accuracy: 0.8148
# Epoch 35/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4241 - accuracy: 0.8178
# Epoch 36/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4238 - accuracy: 0.8165
# Epoch 37/100
# 235/235 [==============================] - 0s 479us/step - loss: 0.4210 - accuracy: 0.8152
# Epoch 38/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4219 - accuracy: 0.8161
# Epoch 39/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4207 - accuracy: 0.8203
# Epoch 40/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4196 - accuracy: 0.8174
# Epoch 41/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4183 - accuracy: 0.8174
# Epoch 42/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4182 - accuracy: 0.8191
# Epoch 43/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4177 - accuracy: 0.8191
# Epoch 44/100
# 235/235 [==============================] - 0s 441us/step - loss: 0.4169 - accuracy: 0.8212
# Epoch 45/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4172 - accuracy: 0.8203
# Epoch 46/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4150 - accuracy: 0.8199
# Epoch 47/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4153 - accuracy: 0.8212
# Epoch 48/100
# 235/235 [==============================] - 0s 453us/step - loss: 0.4137 - accuracy: 0.8178
# Epoch 49/100
# 235/235 [==============================] - 0s 458us/step - loss: 0.4135 - accuracy: 0.8199
# Epoch 50/100
# 235/235 [==============================] - 0s 462us/step - loss: 0.4131 - accuracy: 0.8182
# Epoch 51/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4129 - accuracy: 0.8229
# Epoch 52/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4121 - accuracy: 0.8199
# Epoch 53/100
# 235/235 [==============================] - 0s 445us/step - loss: 0.4128 - accuracy: 0.8229
# Epoch 54/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4118 - accuracy: 0.8178
# Epoch 55/100
# 235/235 [==============================] - 0s 449us/step - loss: 0.4112 - accuracy: 0.8225
# Epoch 56/100
# 235/235 [==============================] - 0s 462us/step - loss: 0.4122 - accuracy: 0.8186
# Epoch 57/100
# ...
# Epoch 57/100
# 167/167 [==============================] - 0s 452us/step - loss: 0.4328 - accuracy: 0.8169
# Epoch 58/100
# 167/167 [==============================] - 0s 458us/step - loss: 0.4322 - accuracy: 0.8169
# Epoch 59/100
# 167/167 [==============================] - 0s 494us/step - loss: 0.4306 - accuracy: 0.8157
# Epoch 60/100
# 167/167 [==============================] - 0s 482us/step - loss: 0.4310 - accuracy: 0.8169
# Epoch 61/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4296 - accuracy: 0.8181
# Epoch 62/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4292 - accuracy: 0.8217
# Epoch 63/100
# 167/167 [==============================] - 0s 458us/step - loss: 0.4277 - accuracy: 0.8235
# Epoch 64/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4283 - accuracy: 0.8157
# Epoch 65/100
# 167/167 [==============================] - 0s 452us/step - loss: 0.4272 - accuracy: 0.8211
# Epoch 66/100
# 167/167 [==============================] - 0s 452us/step - loss: 0.4248 - accuracy: 0.8205
# Epoch 67/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4238 - accuracy: 0.8181
# Epoch 68/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4221 - accuracy: 0.8187
# Epoch 69/100
# 167/167 [==============================] - 0s 458us/step - loss: 0.4205 - accuracy: 0.8181
# Epoch 70/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4194 - accuracy: 0.8229
# Epoch 71/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4178 - accuracy: 0.8229
# Epoch 72/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4156 - accuracy: 0.8199
# Epoch 73/100
# 167/167 [==============================] - 0s 458us/step - loss: 0.4137 - accuracy: 0.8253
# Epoch 74/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4144 - accuracy: 0.8199
# Epoch 75/100
# 167/167 [==============================] - 0s 446us/step - loss: 0.4132 - accuracy: 0.8259
# Epoch 76/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4123 - accuracy: 0.8277
# Epoch 77/100
# 167/167 [==============================] - 0s 458us/step - loss: 0.4123 - accuracy: 0.8283
# Epoch 78/100
# 167/167 [==============================] - 0s 482us/step - loss: 0.4114 - accuracy: 0.8187
# Epoch 79/100
# 167/167 [==============================] - 0s 488us/step - loss: 0.4100 - accuracy: 0.8289
# Epoch 80/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4092 - accuracy: 0.8223
# Epoch 81/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4095 - accuracy: 0.8247
# Epoch 82/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4081 - accuracy: 0.8247
# Epoch 83/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4080 - accuracy: 0.8277
# Epoch 84/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4053 - accuracy: 0.8229
# Epoch 85/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4076 - accuracy: 0.8259
# Epoch 86/100
# 167/167 [==============================] - 0s 476us/step - loss: 0.4059 - accuracy: 0.8271
# Epoch 87/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4042 - accuracy: 0.8289
# Epoch 88/100
# 167/167 [==============================] - 0s 482us/step - loss: 0.4045 - accuracy: 0.8295
# Epoch 89/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4045 - accuracy: 0.8277
# Epoch 90/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4041 - accuracy: 0.8313
# Epoch 91/100
# 167/167 [==============================] - 0s 464us/step - loss: 0.4031 - accuracy: 0.8289
# Epoch 92/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4049 - accuracy: 0.8277
# Epoch 93/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4019 - accuracy: 0.8325
# Epoch 94/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4019 - accuracy: 0.8307
# Epoch 95/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4013 - accuracy: 0.8337
# Epoch 96/100
# 167/167 [==============================] - 0s 506us/step - loss: 0.4005 - accuracy: 0.8283
# Epoch 97/100
# 167/167 [==============================] - 0s 519us/step - loss: 0.3997 - accuracy: 0.8325
# Epoch 98/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.4002 - accuracy: 0.8301
# Epoch 99/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.3997 - accuracy: 0.8295
# Epoch 100/100
# 167/167 [==============================] - 0s 470us/step - loss: 0.3982 - accuracy: 0.8319
# 6/6 [==============================] - 0s 601us/step - loss: 0.4433 - accuracy: 0.7838
# Paul Goldschmidt
# Gathering Player Data
# Epoch 1/100
# d:\Users\Luke\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\arraysetops.py:608: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# 262/262 [==============================] - 0s 453us/step - loss: 0.6885 - accuracy: 0.5138
# Epoch 2/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.6473 - accuracy: 0.6161
# Epoch 3/100
# 262/262 [==============================] - 0s 441us/step - loss: 0.6203 - accuracy: 0.6788
# Epoch 4/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5957 - accuracy: 0.7055
# Epoch 5/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5740 - accuracy: 0.7208
# Epoch 6/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5551 - accuracy: 0.7487
# Epoch 7/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5383 - accuracy: 0.7548
# Epoch 8/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5233 - accuracy: 0.7636
# Epoch 9/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.5096 - accuracy: 0.7754
# Epoch 10/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4977 - accuracy: 0.7796
# Epoch 11/100
# 262/262 [==============================] - 0s 479us/step - loss: 0.4881 - accuracy: 0.7807
# Epoch 12/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4801 - accuracy: 0.7857
# Epoch 13/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4730 - accuracy: 0.7857
# Epoch 14/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4667 - accuracy: 0.7926
# Epoch 15/100
# 262/262 [==============================] - 0s 464us/step - loss: 0.4617 - accuracy: 0.7953
# Epoch 16/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4576 - accuracy: 0.7949
# Epoch 17/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4548 - accuracy: 0.8018
# Epoch 18/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4513 - accuracy: 0.8033
# Epoch 19/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4490 - accuracy: 0.8033
# Epoch 20/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4471 - accuracy: 0.8056
# Epoch 21/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4451 - accuracy: 0.8021
# Epoch 22/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4426 - accuracy: 0.8037
# Epoch 23/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4401 - accuracy: 0.8052
# Epoch 24/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4395 - accuracy: 0.8056
# Epoch 25/100
# 262/262 [==============================] - 0s 487us/step - loss: 0.4366 - accuracy: 0.8090
# Epoch 26/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4348 - accuracy: 0.8063
# Epoch 27/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4338 - accuracy: 0.8067
# Epoch 28/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4317 - accuracy: 0.8098
# Epoch 29/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4308 - accuracy: 0.8079
# Epoch 30/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4291 - accuracy: 0.8094
# Epoch 31/100
# 262/262 [==============================] - 0s 468us/step - loss: 0.4278 - accuracy: 0.8121
# Epoch 32/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4270 - accuracy: 0.8113
# Epoch 33/100
# 262/262 [==============================] - 0s 464us/step - loss: 0.4259 - accuracy: 0.8117
# Epoch 34/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4242 - accuracy: 0.8144
# Epoch 35/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4238 - accuracy: 0.8136
# Epoch 36/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4220 - accuracy: 0.8132
# Epoch 37/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4212 - accuracy: 0.8132
# Epoch 38/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4202 - accuracy: 0.8147
# Epoch 39/100
# 262/262 [==============================] - 0s 491us/step - loss: 0.4198 - accuracy: 0.8105
# Epoch 40/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4188 - accuracy: 0.8159
# Epoch 41/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4182 - accuracy: 0.8163
# Epoch 42/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4168 - accuracy: 0.8186
# Epoch 43/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4169 - accuracy: 0.8151
# Epoch 44/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4159 - accuracy: 0.8212
# Epoch 45/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4151 - accuracy: 0.8178
# Epoch 46/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4152 - accuracy: 0.8193
# Epoch 47/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4136 - accuracy: 0.8224
# Epoch 48/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4131 - accuracy: 0.8205
# Epoch 49/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.4132 - accuracy: 0.8167
# Epoch 50/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4124 - accuracy: 0.8201
# Epoch 51/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.4122 - accuracy: 0.8220
# Epoch 52/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.4113 - accuracy: 0.8212
# Epoch 53/100
# 262/262 [==============================] - 0s 479us/step - loss: 0.4110 - accuracy: 0.8205
# Epoch 54/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4108 - accuracy: 0.8186
# Epoch 55/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4107 - accuracy: 0.8216
# Epoch 56/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4100 - accuracy: 0.8220
# Epoch 57/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4094 - accuracy: 0.8224
# Epoch 58/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4092 - accuracy: 0.8254
# Epoch 59/100
# 262/262 [==============================] - 0s 472us/step - loss: 0.4087 - accuracy: 0.8193
# Epoch 60/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4084 - accuracy: 0.8220
# Epoch 61/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4082 - accuracy: 0.8270
# Epoch 62/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4077 - accuracy: 0.8205
# Epoch 63/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4068 - accuracy: 0.8228
# Epoch 64/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4075 - accuracy: 0.8205
# Epoch 65/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4069 - accuracy: 0.8239
# Epoch 66/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4061 - accuracy: 0.8216
# Epoch 67/100
# 262/262 [==============================] - 0s 518us/step - loss: 0.4063 - accuracy: 0.8235
# Epoch 68/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4059 - accuracy: 0.8209
# Epoch 69/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4048 - accuracy: 0.8270
# Epoch 70/100
# 262/262 [==============================] - 0s 464us/step - loss: 0.4055 - accuracy: 0.8224
# Epoch 71/100
# 262/262 [==============================] - 0s 468us/step - loss: 0.4050 - accuracy: 0.8220
# Epoch 72/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.4048 - accuracy: 0.8228
# Epoch 73/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4042 - accuracy: 0.8224
# Epoch 74/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4036 - accuracy: 0.8270
# Epoch 75/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4044 - accuracy: 0.8239
# Epoch 76/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4034 - accuracy: 0.8247
# Epoch 77/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4039 - accuracy: 0.8205
# Epoch 78/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4018 - accuracy: 0.8262
# Epoch 79/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.4025 - accuracy: 0.8216
# Epoch 80/100
# 262/262 [==============================] - 0s 491us/step - loss: 0.4028 - accuracy: 0.8239
# Epoch 81/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.4018 - accuracy: 0.8258
# Epoch 82/100
# 262/262 [==============================] - 0s 445us/step - loss: 0.4011 - accuracy: 0.8235
# Epoch 83/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4015 - accuracy: 0.8254
# Epoch 84/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4008 - accuracy: 0.8243
# Epoch 85/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4012 - accuracy: 0.8266
# Epoch 86/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.4009 - accuracy: 0.8254
# Epoch 87/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.4001 - accuracy: 0.8231
# Epoch 88/100
# 262/262 [==============================] - 0s 468us/step - loss: 0.3995 - accuracy: 0.8251
# Epoch 89/100
# 262/262 [==============================] - 0s 472us/step - loss: 0.4002 - accuracy: 0.8224
# Epoch 90/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.3999 - accuracy: 0.8239
# Epoch 91/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.3986 - accuracy: 0.8220
# Epoch 92/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.3992 - accuracy: 0.8251
# Epoch 93/100
# 262/262 [==============================] - 0s 464us/step - loss: 0.3991 - accuracy: 0.8270
# Epoch 94/100
# 262/262 [==============================] - 0s 483us/step - loss: 0.3990 - accuracy: 0.8289
# Epoch 95/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.3983 - accuracy: 0.8262
# Epoch 96/100
# 262/262 [==============================] - 0s 449us/step - loss: 0.3970 - accuracy: 0.8258
# Epoch 97/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.3986 - accuracy: 0.8262
# Epoch 98/100
# 262/262 [==============================] - 0s 453us/step - loss: 0.3968 - accuracy: 0.8251
# Epoch 99/100
# 262/262 [==============================] - 0s 456us/step - loss: 0.3967 - accuracy: 0.8277
# Epoch 100/100
# 262/262 [==============================] - 0s 460us/step - loss: 0.3970 - accuracy: 0.8235
# 10/10 [==============================] - 0s 445us/step - loss: 0.4293 - accuracy: 0.8247
#                   Name     n  Logistic    Neural
# 132        Dj Lemahieu  2309     0.761  0.775439
# 40      Jonathan India  2209     0.699  0.744361
# 82         Kolten Wong  1570     0.749  0.796791
# 39        Yuli Gurriel  2088     0.685  0.728346
# 35      J. D. Martinez  2164     0.751  0.812261
# 21    Brandon Crawford  1832     0.739  0.811927
# 145        Sean Murphy  1397     0.657  0.739645
# 0         Bryce Harper  2075     0.730  0.776062
# 150  Anthony Santander  1537     0.778  0.783784
# 23    Paul Goldschmidt  2366     0.725  0.824742

# %%
print(scores[["n", "Logistic", "Neural"]].mean())
print(scores[["n", "Logistic", "Neural"]].std())
# Out:
# n           1954.700000
# Logistic       0.727400
# Neural         0.779336
# dtype: float64
# n           347.045322
# Logistic      0.037149
# Neural        0.033261
# dtype: float64
